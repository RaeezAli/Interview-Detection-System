# %% [markdown]
# <a href="https://colab.research.google.com/github/RaeezAli/Interview-Detection-System/blob/main/notebooks/emotion_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls ../
# !ls ../notebooks
# Out:
# bin	 dev	 lib	 media	    proc	       run   tmp
# boot	 etc	 lib32	 mnt	    python-apt	       sbin  tools
# content  home	 lib64	 notebooks  python-apt.tar.xz  srv   usr
# datalab  kaggle  libx32  opt	    root	       sys   var

# %%
import os

os.makedirs("../notebooks", exist_ok=True)
# !ls ../
# Out:
# bin	 dev	 lib	 media	    proc	       run   tmp
# boot	 etc	 lib32	 mnt	    python-apt	       sbin  tools
# content  home	 lib64	 notebooks  python-apt.tar.xz  srv   usr
# datalab  kaggle  libx32  opt	    root	       sys   var
